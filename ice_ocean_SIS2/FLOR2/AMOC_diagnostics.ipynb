# %%
from midas.rectgrid import *
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
import hashlib
import glob

# %%
EXP=[]
EXP.append({'name':'FLOR2_LM3_SIS2_baseline1',\
            'root_path':'/ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_143f313a473f61eac8842259c729dca84329000b/',\
            'platform':'gfdl.ncrc2-default-prod'})
EXP.append({'name':'FLOR2_LM3_SIS2_baseline0_KHTR_600_DELTA_EDD_NEG1',\
           'root_path':'/ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_d00d00100e7cc79130abeadbbda1997f698f6659/',\
            'platform':'gfdl.ncrc2-intel-prod'})
EXP.append({'name':'FLOR2_LM3_SIS_baseline0',\
           'root_path':'/ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_d00d00100e7cc79130abeadbbda1997f698f6659/',\
            'platform':'gfdl.ncrc2-intel-prod'})

# %%
sgrid=supergrid(file='ocean_hgrid.nc',tripolar_n=True,cyclic_x=True)
grid=quadmesh(supergrid=sgrid)
grid.D=nc.Dataset('topog.nc').variables['depth'][:]
grid.wet=np.zeros(grid.D.shape)
grid.wet[grid.D>0.]=1.
grid.lath=grid.y_T[:,grid.im/4]
mask=nc.Dataset('basin_codes.nc').variables['basin'][:]
AtlMask=mask.copy()
AtlMask[mask==1]=0.
AtlMask[mask==2]=1.
AtlMask[mask==4]=1.
AtlMask[mask==6]=1.
AtlMask[mask==8]=1.
AtlMask[mask==9]=1.
AtlMask[AtlMask>1]=0.
grid.mask=AtlMask

# %%
S=[]
for exp in EXP:
    listing=exp['root_path']+exp['name']+'/'+exp['platform']+'/history/*/*.ocean_month.nc'
    listing=glob.glob(listing)
    listing=sorted(listing)
    print listing[0],listing[-1]
    S.append(state(MFpath=listing,grid=grid,\
                   fields=['PRCmE','net_heat_surface'],verbose=False,\
#                   date_bounds=[datetime.datetime(1992,1,2),datetime.datetime(2004,1,1)],\
                   default_calendar='gregorian'))
#    print S[-1].var_dict['PRCmE']['dates']
    S[-1].grid.mask=grid.mask
    S[-1].mask_where('PRCmE','grid.mask == 0' )
    S[-1].adjust_thickness('PRCmE')
    S[-1].volume_integral('PRCmE','X',normalize=False)
    S[-1].mask_where('net_heat_surface','grid.mask == 0' )
    S[-1].volume_integral('net_heat_surface','X',normalize=False)
# Out:
# /ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_143f313a473f61eac8842259c729dca84329000b/FLOR2_LM3_SIS2_baseline1/gfdl.ncrc2-default-prod/history/19800101.nc/19800101.ocean_month.nc /ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_143f313a473f61eac8842259c729dca84329000b/FLOR2_LM3_SIS2_baseline1/gfdl.ncrc2-default-prod/history/20120101.nc/20120101.ocean_month.nc
# /ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_d00d00100e7cc79130abeadbbda1997f698f6659/FLOR2_LM3_SIS2_baseline0_KHTR_600_DELTA_EDD_NEG1/gfdl.ncrc2-intel-prod/history/19800101.nc/19800101.ocean_month.nc
#  /ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_d00d00100e7cc79130abeadbbda1997f698f6659/FLOR2_LM3_SIS2_baseline0_KHTR_600_DELTA_EDD_NEG1/gfdl.ncrc2-intel-prod/history/19900101.nc/19900101.ocean_month.nc
# /ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_d00d00100e7cc79130abeadbbda1997f698f6659/FLOR2_LM3_SIS_baseline0/gfdl.ncrc2-intel-prod/history/19800101.nc/19800101.ocean_month.nc
#  /ptmp/Matthew.Harrison/archive/Matthew.Harrison/ulm_mom6_d00d00100e7cc79130abeadbbda1997f698f6659/FLOR2_LM3_SIS_baseline0/gfdl.ncrc2-intel-prod/history/19880101.nc/19880101.ocean_month.nc

# %%
# %matplotlib inline
print AtlMask.max()
plt.pcolormesh(AtlMask)
# Out:
# 1.0

# %%
# %matplotlib inline

fig=plt.figure(1,figsize=(12,6))
ax1=fig.add_subplot(111)

colList=['b','r','g','c','k'][::-1]
x=grid.lath
for res,exp in zip(S,EXP):
    col=colList.pop()
    print col,exp['name']
    res.time_avg('PRCmE_xint')
    y=res.PRCmE_xint_tav
    y=sq(np.ma.filled(y,0.))
    y=np.sum(y)-np.cumsum(y)
    ax1.plot(x,y/1.e9,color=col,label=exp['name'])

ax1.plot([x[0],x[-1]],[-0.28,-0.28],color='k',linestyle='dashed',label='Talley08')
ax1.plot([-30.,-30.],[-0.6,0.75],color='k',linestyle='dashed',)
ax1.set_xlim(-38,90)
#ax1.set_ylim(-.6,.75)
plt.legend()
ax1.grid()
ax1.set_title('Implied Southward FW Transport (Sv)')
# Out:
# b FLOR2_LM3_SIS2_baseline1
# r FLOR2_LM3_SIS2_baseline0_KHTR_600_DELTA_EDD_NEG1
# g FLOR2_LM3_SIS_baseline0

# %%
# %matplotlib inline

fig=plt.figure(1,figsize=(12,6))
ax1=fig.add_subplot(111)

colList=['b','r','g','c','k'][::-1]
x=grid.lath

#rho=1.035e3
#cp=3989.

for res,exp in zip(S,EXP):
    col=colList.pop()
    print col,exp['name']
    res.time_avg('net_heat_surface_xint')
    y=res.net_heat_surface_xint_tav
    y=sq(np.ma.filled(y,0.))
    y=np.sum(y)-np.cumsum(y)
    ax1.plot(x,-y/1.e15,color=col,label=exp['name'])

#ax1.plot([x[0],x[-1]],[-0.28,-0.28],color='k',linestyle='dashed',label='Talley08')
#ax1.plot([-30.,-30.],[-0.6,0.75],color='k',linestyle='dashed',)
ax1.set_xlim(-38,90)
#ax1.set_ylim(-2,1.3)
plt.legend()
ax1.grid()
ax1.set_title('Implied Northward Heat Transport (PW)')
# Out:
# b FLOR2_LM3_SIS2_baseline1
# r FLOR2_LM3_SIS2_baseline0_KHTR_600_DELTA_EDD_NEG1
# g FLOR2_LM3_SIS_baseline0

# %%
S=[]
for exp in EXP:
    listing=exp['root_path']+exp['name']+'/'+exp['platform']+'/history/*/*.ocean_annual.nc'
    listing=glob.glob(listing)
    listing=sorted(listing)
    S.append(state(MFpath=listing,grid=grid,fields=['vh'],verbose=False))
    S[-1].grid.mask=grid.mask
    S[-1].adjust_thickness('vh')
    S[-1].mask_where('vh','grid.mask == 0' )

# %%
# %matplotlib inline

fig=plt.figure(1,figsize=(12,6))
ax1=fig.add_subplot(111)
x=grid.lath
indx=np.where(np.logical_and(x>40,x<50.))
colList=['b','r','g','c','k'][::-1]
for res,exp in zip(S,EXP):
    time=instance_to_datetime(res.var_dict['vh']['dates'])
    y=res.vh
    y=np.ma.sum(y,axis=3)
    y=np.ma.filled(y,0.)
    y=np.cumsum(y,axis=1)/1.e6
    y=sq(y[:,:,indx])
    y=np.max(y,axis=2)
    y=np.max(y,axis=1)
    ax1.plot_date(time,y,linestyle='solid',color=colList.pop(),label=exp['name'])

plt.legend()

# %%
# %matplotlib inline

fig=plt.figure(1,figsize=(12,6))
ax1=fig.add_subplot(111)

colList=['b','r','g','c'][::-1]
x=grid.lath
y=S[0].var_dict['vh']['zax_data']

X,Y=np.meshgrid(x,y)

res=S[0]
res.time_avg('vh')

z=np.ma.sum(res.vh_tav,axis=3)
print z.shape
z=sq(np.ma.filled(z,0.))
print z.shape
z=np.cumsum(z,axis=0)
cf=ax1.pcolormesh(X,-Y,z/1.e6,vmin=-8,vmax=20,cmap=plt.cm.spectral)
ax1.contour(X,-Y,z/1.e6,np.linspace(-30,30,15),colors='k')
#ax1.plot([x[0],x[-1]],[-0.28,-0.28],color='k',linestyle='dashed',label='Talley08')
#ax1.plot([-30.,-30.],[-0.6,0.75],color='k',linestyle='dashed',)
ax1.set_xlim(-35,90)
ax1.set_ylim(-5500,0)
ax1.grid()
plt.colorbar(cf,ax=ax1)
tit=EXP[0]['name']+' Atlantic Overturning Streamfunction (Sv)'
ax1.set_title(tit)
# Out:
# (1, 75, 320)
# (75, 320)

# %%
S=[]
for exp in EXP:
    listing=exp['root_path']+exp['name']+'/'+exp['platform']+'/history/*/*.ocean_annual.nc'
    listing=glob.glob(listing)
    listing=sorted(listing)
    S.append(state(MFpath=listing,grid=grid,fields=['temp','salt'],verbose=False))
    S[-1].grid.mask=grid.mask
    S[-1].adjust_thickness('temp')
    S[-1].adjust_thickness('salt')
    S[-1].mask_where('temp','grid.mask == 0' )
    S[-1].mask_where('salt','grid.mask == 0' )

# %%
# %matplotlib inline

fig=plt.figure(1,figsize=(12,6))
ax1=fig.add_subplot(111)

colList=['b','r','g','c'][::-1]
x=grid.lath
y=S[0].var_dict['temp']['zax_data']

X,Y=np.meshgrid(x,y)

res=S[0]
res.volume_integral('temp','X',normalize=True)
z=sq(res.temp_xav)
cf=ax1.pcolormesh(X,-Y,z,cmap=plt.cm.spectral)
#ax1.contour(X,-Y,z,np.linspace(-2,12,.5),colors='k')
#ax1.plot([x[0],x[-1]],[-0.28,-0.28],color='k',linestyle='dashed',label='Talley08')
#ax1.plot([-30.,-30.],[-0.6,0.75],color='k',linestyle='dashed',)
ax1.set_xlim(-35,90)
ax1.set_ylim(-5500,0)
ax1.grid()
plt.colorbar(cf,ax=ax1)
tit=EXP[0]['name']+' Atlantic Temperature (degC)'
ax1.set_title(tit)

# %%
date_start = datetime.datetime(1990,1,1)
date_end = datetime.datetime(1990,12,31)
path_obs_sic = '/net3/mjh/data/noaa.oisst.v2/icec.wkmean.1990-2012.nc'
grid_sic = quadmesh(path_obs_sic,cyclic=True,var='ICEC')
Obs=state(path_obs_sic,grid=grid_sic,fields=['ICEC'],verbose=False,\
    default_calendar='gregorian',date_bounds=[date_start,date_end])
Obs_regrid=Obs.horiz_interp('ICEC',target=grid)
print '0001'
si_max=np.max(Obs_regrid.ICEC,axis=0)[np.newaxis,:]
si_min=np.min(Obs_regrid.ICEC,axis=0)[np.newaxis,:]
vdict=Obs_regrid.var_dict['ICEC'].copy()
vdict['T']=None
Obs_regrid.add_field_from_array(si_max,'CiMax',var_dict=vdict)
Obs_regrid.add_field_from_array(si_min,'CiMin',var_dict=vdict)
# Out:
# Memory usage hinterp (pre): 148840 (kb)
# lon_in.shape= (181, 360)
# (53, 1, 1, 360)

# %%
S=[]
for exp in EXP:
    listing=exp['root_path']+exp['name']+'/'+exp['platform']+'/history/*/*.ice_month.nc'
    listing=glob.glob(listing)
    listing=sorted(listing)
    S.append(state(MFpath=listing,grid=grid,fields=['CN','HI'],verbose=False))
    S[-1].grid.mask=grid.mask
    S[-1].mask_where('CN','grid.mask == 0' )
    S[-1].mask_where('HI','grid.mask == 0' )
    CNmax=np.max(np.sum(S[-1].CN,axis=1),axis=0)[np.newaxis,np.newaxis,:]
    CNmin=np.min(np.sum(S[-1].CN,axis=1),axis=0)[np.newaxis,np.newaxis,:]
    vdict=S[-1].var_dict['CN'].copy()
    vdict['Z']=None
    vdict['T']=None
    S[-1].add_field_from_array(CNmax,'ICEC_max',var_dict=vdict)
    S[-1].add_field_from_array(CNmin,'ICEC_min',var_dict=vdict)
